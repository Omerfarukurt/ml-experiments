# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("bank-additional-full.csv",delimiter=";")

# %%
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
# Out:
# marital
# married     25008
# single      11568
# divorced     4612
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %%
for column in data.columns:
    if data[column].dtype == 'object':  # Sadece kategorik (object) sütunlar için
        most_common = data[column][data[column] != 'unknown'].mode()
        if not most_common.empty:
            data[column] = data[column].replace('unknown', most_common[0]) #UNKNOWN OLAN BÜTÜN DEĞERLERİ O SÜTUN İÇİNDE EN COK TEKRA EDEN DEĞERLE DEĞİŞTİRDİK

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
cat_cols=data.select_dtypes('object')

# %%
plt.figure(figsize=(8,8))
sns.barplot(data['job'],color='red')
plt.legend()
plt.xlabel('Değerler')
plt.ylabel('İş')
# Out:
# C:\Users\Ömer faruk\AppData\Local\Temp\ipykernel_14340\2222296077.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Text(0, 0.5, 'İş')

# %%
sns.histplot(data['month'],kde=True,bins=30)
# Out:
# <Axes: xlabel='month', ylabel='Count'>

# %%
sns.histplot(data['day_of_week'],bins=7,color='yellow',)
# Out:
# <Axes: xlabel='day_of_week', ylabel='Count'>

# %%
sns.histplot(data=data,x=data['age'],hue=data['y'],kde=True,bins=10,palette='Set1')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=data,x=data['job'],hue=data['y'],kde=True,bins=10,palette='Set1')
# Out:
# <Axes: xlabel='job', ylabel='Count'>

# %%
plt.figure(figsize=(20,10))
sns.histplot(data=data,x=data['duration'],hue=data['y'],kde=True,palette='Set1')
plt.xlim(1,1000)
# Out:
# (1.0, 1000.0)

# %% [markdown]
# ŞUANA KADAR VERİDEN ÇIKARDIGIM GENELLİKLE 30-40 YAŞ ARALIĞI , YÖNETİCİLERİN , ÜNİVERSİTE BİTİRENLERİN (ÇOK OLMASADA LİSE EĞİTİMİ ALANAR) , EVLİLERİN VE 200 SANİYE ORTALAMA İLE KONUŞANLARIN KAMPANYAYA KATILDIĞI

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder,MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,roc_auc_score,confusion_matrix

# %%
data.head()
encode=LabelEncoder()

# %%
for i in cat_cols:
    data[i]=encode.fit_transform(data[i])

# %%
X=data.drop('y',axis=1)
y=data['y']

# %%
col_names=X.columns

# %%
scaler=MinMaxScaler()

# %%
X=scaler.fit_transform(X)

# %%
X=pd.DataFrame(data=X,columns=col_names)

# %%
X.head()
# Out:
#         age  job  marital  education  default  housing  loan  contact  \
# 0  0.481481  0.3      0.5   0.000000      0.0      0.0   0.0      1.0
# 1  0.493827  0.7      0.5   0.500000      0.0      0.0   0.0      1.0
# 2  0.246914  0.7      0.5   0.500000      0.0      1.0   0.0      1.0
# 3  0.283951  0.0      0.5   0.166667      0.0      0.0   0.0      1.0
# 4  0.481481  0.7      0.5   0.500000      0.0      0.0   1.0      1.0
#
#       month  day_of_week  duration  campaign  pdays  previous  poutcome  \
# 0  0.666667         0.25  0.053070       0.0    1.0       0.0       0.5
# 1  0.666667         0.25  0.030297       0.0    1.0       0.0       0.5
# 2  0.666667         0.25  0.045954       0.0    1.0       0.0       0.5
# 3  0.666667         0.25  0.030704       0.0    1.0       0.0       0.5
# 4  0.666667         0.25  0.062424       0.0    1.0       0.0       0.5
#
#    emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)

# %%
tree_clf=DecisionTreeClassifier(criterion='entropy',max_depth=7,random_state=20)

# %%
tree_clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=7, random_state=20)

# %%
y_pred=tree_clf.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9130814800427309

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[17575,   692],
#        [ 1098,  1229]], dtype=int64)

# %%
data['y'].value_counts()
# Out:
# y
# 0    36548
# 1     4640
# Name: count, dtype: int64

# %%
tree_clf.feature_importances_
# Out:
# array([0.02103584, 0.00346433, 0.00136426, 0.00204749, 0.        ,
#        0.00109411, 0.        , 0.        , 0.0183802 , 0.00426041,
#        0.48254542, 0.00753326, 0.03042129, 0.00065144, 0.00629864,
#        0.00237483, 0.00600221, 0.08679052, 0.03242325, 0.29331249])

# %%
important=tree_clf.feature_importances_
names=X.columns

# %%
imp=sorted(zip(important,names),reverse=True)

# %%
for important,features in imp:
    print(f'{features} önem derecesi:{important}')
# Out:
# duration önem derecesi:0.4825454236950121
# nr.employed önem derecesi:0.2933124855819029
# cons.conf.idx önem derecesi:0.08679052390515529
# euribor3m önem derecesi:0.03242325096524982
# pdays önem derecesi:0.030421293495999147
# age önem derecesi:0.021035842809428846
# month önem derecesi:0.018380198446277023
# campaign önem derecesi:0.007533260035214599
# poutcome önem derecesi:0.006298638936212758
# cons.price.idx önem derecesi:0.00600221392099738
# day_of_week önem derecesi:0.004260406680888393
# job önem derecesi:0.0034643321716119357
# emp.var.rate önem derecesi:0.0023748288748809848
# education önem derecesi:0.0020474939276654783
# marital önem derecesi:0.0013642567250517056
# housing önem derecesi:0.001094106262122995
# previous önem derecesi:0.0006514435663286061
# loan önem derecesi:0.0
# default önem derecesi:0.0
# contact önem derecesi:0.0

# %%
df=data.copy()
onemsiz=[]

# %%
for important,features in imp:
    if important<0.005:
        onemsiz.append(features)

# %%
onemsiz
# Out:
# ['day_of_week',
#  'job',
#  'emp.var.rate',
#  'education',
#  'marital',
#  'housing',
#  'previous',
#  'loan',
#  'default',
#  'contact']

# %%
df.drop(columns=onemsiz,axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   month           41188 non-null  int32
#  2   duration        41188 non-null  int64
#  3   campaign        41188 non-null  int64
#  4   pdays           41188 non-null  int64
#  5   poutcome        41188 non-null  int32
#  6   cons.price.idx  41188 non-null  float64
#  7   cons.conf.idx   41188 non-null  float64
#  8   euribor3m       41188 non-null  float64
#  9   nr.employed     41188 non-null  float64
#  10  y               41188 non-null  int64
# dtypes: float64(4), int32(2), int64(5)
# memory usage: 3.1 MB

# %%
X_1=df.drop('y',axis=1)
y_1=df['y']

# %%
X_1_train,X_1_test,y_1_train,y_1_test=train_test_split(X_1,y_1,test_size=0.2,random_state=42)

# %%
X_1_cols=X_1.columns

# %%
X_1_train=scaler.fit_transform(X_1_train)
X_1_test=scaler.transform(X_1_test)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but MinMaxScaler was fitted without feature names
#   warnings.warn(

# %%
X_1_test=pd.DataFrame(X_1_test,columns=X_1_cols)

# %%
tree_clf_2=DecisionTreeClassifier(criterion='entropy',max_depth=6,,random_state=42)
# Out:
#   Cell In[376], line 1
#     tree_clf_2=DecisionTreeClassifier(criterion='entropy',max_depth=6,,random_state=42)
#                                                                       ^
# SyntaxError: invalid syntax

# %%
tree_clf_2.fit(X_1_train,y_1_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, random_state=42)

# %%
y_pred_2=tree_clf_2.predict(X_1_test)

# %%
confusion_matrix(y_1_test,y_pred_2)
# Out:
# array([[   0, 7303],
#        [   0,  935]], dtype=int64)

# %%
accuracy_score(y_1_test,y_pred_2)
# Out:
# 0.11349842194707453

# %%
# Out:
# 12556    0
# 35451    0
# 30592    0
# 17914    0
# 3315     0
#         ..
# 6265     0
# 11284    0
# 38158    1
# 860      0
# 15795    0
# Name: y, Length: 32950, dtype: int64
